# %%
"""
import Default Package
"""
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import importlib as il
from pprint import pprint as pp

# %%
"""
GoogleAuth and Drive Init
"""

from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive

gauth = GoogleAuth()
gauth.LocalWebserverAuth()
drive = GoogleDrive(gauth)

# %%
"""
Get CSV File in GoolgeDrive
"""
# Auto-iterate through all files that matches this query
file_list = drive.ListFile({'q': "title = '2021_01_25_PH_.csv'"}).GetList()
file_list[0]['id']

# for tmpFile in file_list:
#   print('title: %s, id: %s' % (file1['title'], file1['id']))
#   file = tmpFile
#   del(file1)
# Out:
# '1vz-E-_-YHsMceGT_6XHhMuqbbAXeRoNO'

# %%
fileId = file_list[0]['id']
path = 'https://drive.google.com/uc?export=download&id='+fileId
df = pd.read_csv(path
                 ,encoding='utf-8'
                 ,index_col='time')
df
# Out:
#         shcode  drate   price   volume  cdhrem  cshrem  bdhrem  bshrem  \
# time
# 91308     5930   0.35   87100  2506639       0       0    8948   30303
# 91308     5380  -0.78  255000   266160       0       0    2086    1824
# 91309    35420   1.60  349000   290358       0       0    2999    3436
# 91311      660   1.95  131000   267960    1917    3845   51585   15584
# 91312     5930   0.46   87200  2508127       0       0    9023   29212
# ...        ...    ...     ...      ...     ...     ...     ...     ...
# 174027  139480   5.46  183500   434660       0       0    3998    2785
# 174905  139480   5.46  183500   434660       0       0    3998    2794
# 175002  139480   5.46  183500   436241       0       0    3998    2785
# 175904  139480   5.46  183500   436241       0       0    3998    2794
# 180003  139480   5.46  183500   436241       0       0    3998    2785
#
#         cdhvolume  cshvolume  bdhvolume  bshvolume  tdvolume  tsvolume    tvol
# time
# 91308      112736      72488     647316     471258    751104    513443 -237661
# 91308        3378       2172      21826      43890     23118     44238   21120
# 91309        3028       1947      65412      78988     65441     77499   12058
# 91311       13408       8621      67037      73166     26943     62358   35415
# 91312      112736      72488     647496     470167    751209    513443 -237766
# ...           ...        ...        ...        ...       ...       ...     ...
# 174027       6276       7983      50252      60509     52530     65707   13177
# 174905       6276       7983      50252      60518     52530     65707   13177
# 175002       6276       7983      50252      60518     52530     65716   13186
# 175904       6276       7983      50252      60527     52530     65716   13186
# 180003       6276       7983      50252      60527     52530     65725   13195
#
# [95652 rows x 15 columns]

# %%
import Funcs as fc
il.reload(fc)
# Out:
# <module 'Funcs' from '/Users/youngkwanji/Documents/00.MyFolder/HM/DataAnalysis/src/Funcs.py'>

# %%
dfPhInfo = fc.prePrcssPhInfo(df)
samsungPH = dfPhInfo[dfPhInfo['shcode'] == '005930']
samsungPH

sns.pairplot(samsungPH)

# %%
sampleA = pd.DataFrame(data= samsungPH, columns=['drate'])
sampleA['preBDist'] = samsungPH['bdhvolume'] - samsungPH['bshvolume']
sampleA['preCDist'] = samsungPH['cdhvolume'] - samsungPH['cshvolume']
sampleA['preTDist'] = samsungPH['tdvolume'] - samsungPH['tsvolume']

sampleA
# Out:
#         drate  preBDist  preCDist  preTDist
# time
# 91308    0.35    176058     40248    237661
# 91312    0.46    177329     40248    237766
# 91315    0.46    177386     40248    237766
# 91318    0.35    198595     48256    243216
# 91323    0.35    196608     48256    243871
# ...       ...       ...       ...       ...
# 152949   3.23    183435     20555   -232434
# 152955   3.23    193775     20555   -232434
# 153008   3.00    194175     20555      7469
# 172327   3.00    194625     20555      7469
# 173009   3.00    194625     20555      7919
#
# [11801 rows x 4 columns]

# %%
fc.showClusterMap(sampleA)

plt.close()

# %%
plt.scatter(sampleA.index, sampleA['drate'],c='red')
plt.scatter(sampleA.index, sampleA['preTDist']/100000,c='green')
# , sampleA['preTDist']
# plt.scatter(sampleA['preTDist'])
# plt.scatter(sampleA['drate'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
samsungCorr = samsungPH.corrwith(samsungPH['preDist'])
samsungCorr
# Out:
# drate       -0.602605
# price       -0.601745
# volume      -0.662836
# cdhrem       0.032565
# cshrem       0.077832
# bdhrem      -0.047710
# bshrem      -0.262233
# cdhvolume   -0.681248
# cshvolume   -0.592421
# bdhvolume   -0.581515
# bshvolume   -0.731342
# tdvolume    -0.622666
# tsvolume    -0.685455
# tvol        -0.928709
# preDist      1.000000
# dtype: float64

# %%
# plt.scatter(samsungPH['bshvolume'], samsungPH['drate'])
# plt.show

# %%
d = {'col1': [1, 2], 'col2': [3, 4]}
df = pd.DataFrame(data=d)
df


d2 = {'col1': df, 'col2': df}
pp(d2)
# Out:
#    col1  col2
# 0     1     3
# 1     2     4
# {'col1':    col1  col2
# 0     1     3
# 1     2     4,
#  'col2':    col1  col2
# 0     1     3
# 1     2     4}

# %%
samsungPH.corrwith(samsungPH['drate'])
# samsungS3.corrwith(samsungS3['drate'])
# Out:
# drate        1.000000
# price        0.999951
# volume      -0.735340
# cdhrem      -0.134815
# cshrem      -0.071412
# bdhrem      -0.109704
# bshrem      -0.069914
# cdhvolume   -0.768452
# cshvolume   -0.735987
# bdhvolume   -0.746088
# bshvolume   -0.493799
# tdvolume    -0.763155
# tsvolume    -0.709472
# tvol         0.808702
# dtype: float64

# %%
samsungS3.corrwith(samsungS3['drate'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-669a9ea4dbc9> in <module>
# ----> 1 samsungS3.corrwith(samsungS3['drate'])
#
# NameError: name 'samsungS3' is not defined

# %%
# Out:
#        shcode  drate   price   volume  ...  bshvolume  tdvolume  tsvolume    tvol
# time                                   ...
# 90928  000660  -2.63  129500   570955  ...      32787    157109     33310 -123799
# 90929  005930  -1.00   88800  2249478  ...     279851    856889    302582 -554307
# 90929  005380  -2.90  251500   560956  ...      74429     83425     53201  -30224
# 90930  035420   2.71  322500   198305  ...      46017     26450     46757   20307
# 90933  005490  -0.18  283000    33046  ...      11215     16856     11331   -5525
# 90933  017670  -0.39  254000    28811  ...       3931      6500      3972   -2528
# 90934  066570  -0.71  139000   138734  ...      19076     52504     16835  -35669
# 90934  096770  -1.96  275500   136184  ...      22603     17942     22598    4656
# 90936  006400  -0.27  752000    39117  ...       6119     19533      6012  -13521
# 90936  010140   0.43    7060   600765  ...     115401    120550    118216   -2334
# 90937  032640  -0.81   12300   299283  ...      27673     42770     18559  -24211
# 90940  034220  -1.22   20200   385296  ...      66406     72180     67362   -4818
# 90940  139480   0.56  180500    34829  ...       3036      9050      3000   -6050
# 90942  009540  -0.86  115000    16299  ...       6090      5433      5909     476
# 90942  009150   1.72  207000   240158  ...      43482     33058     40940    7882
# 90943  024110  -0.45    8840   262639  ...      13975     56758     14724  -42034
# 90946  001040  -0.48  103000     8557  ...       3329      2570      1542   -1028
# 90948  035720   0.88  458500    69280  ...       8097     15904      8285   -7619
# 90949  068270  -5.11  362000   622284  ...      37281     86314     38130  -48184
#
# [19 rows x 15 columns]
